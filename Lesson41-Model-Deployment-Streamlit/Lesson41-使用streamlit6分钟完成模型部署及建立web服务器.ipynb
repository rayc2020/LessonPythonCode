# %% [markdown]
# ## 第41课 使用streamlit6分钟完成模型部署及建立web服务器
#
# Python零基础学习建模：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode
#
# https://www.streamlit.io/

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson41-ML.png')

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson41-ML1.png')

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson41-ML2.png')
