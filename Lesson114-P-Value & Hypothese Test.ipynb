# %% [markdown]
# # 第114讲 P-Value & Hypothese Test & Normality
#
# ## Python学习：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# ## Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode

# %%
from IPython.display import Image
Image(filename='D:\python\Project0-Python-MachineLearning\Lesson113-1.png')

# %% [markdown]
# In the majority of analyses, an alpha of 0.05 is used as the cutoff for significance. If the p-value is less than 0.05, we reject the null hypothesis that there's no difference between the means and conclude that a significant difference does exist. If the p-value is larger than 0.05, we cannot conclude that a significant difference exists.

# %%
from IPython.display import Image
Image(filename='D:\python\Project0-Python-MachineLearning\Lesson113-8.jpg')

# %%
from IPython.display import Image
Image(filename='D:\python\Project0-Python-MachineLearning\Lesson113-4.png')

# %%
from IPython.display import Image
Image(filename='D:\python\Project0-Python-MachineLearning\Lesson113-5.png')

# %% [markdown]
# Step 1: Specify the Null Hypothesis. ...
# Step 2: Specify the Alternative Hypothesis. ...
# Step 3: Set the Significance Level (a) ...
# Step 4: Calculate the Test Statistic and Corresponding P-Value. ...
# Step 5: Drawing a Conclusion.

# %% [markdown]
# 1. Normality Tests - data has a Gaussian distribution.
# 2. Correlation Tests - check if two samples are related
# 3. Stationary Tests - to check if a time series is stationary or not
# 4. Parametric Statistical Hypothesis Tests -  to compare data samples
# 5. Nonparametric Statistical Hypothesis Tests - Tests whether the distributions of two independent samples are equal or not

# %% [markdown]
# ## 1. Normality Tests - data has a Gaussian distribution.

# %%
# Example of the Shapiro-Wilk Normality Test
from scipy.stats import shapiro
data = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = shapiro(data)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
# Out:
# stat=0.895, p=0.193
# Probably Gaussian

# %%
from scipy.stats import normaltest
data = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = normaltest(data)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
# Out:
# stat=3.392, p=0.183
# Probably Gaussian
