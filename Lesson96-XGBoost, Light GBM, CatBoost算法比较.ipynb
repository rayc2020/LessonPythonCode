# %% [markdown]
# ## 第96讲 XGBoost, Light GBM, CatBoost算法比较
#
# ## Python学习：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# ## Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-10.png')

# %% [markdown]
# Light GBM is almost 7+ times faster than XGBOOST and is a much better approach when dealing with large datasets
#
# Unlike CatBoost or LGBM, XGBoost cannot handle categorical features by itself, it only accepts numerical values similar to Random Forest. Therefore one has to perform various encodings like label encoding, mean encoding or one-hot encoding before supplying categorical data to XGBoost

# %% [markdown]
# Light GBM is a fast, distributed, high-performance gradient boosting framework based on decision tree algorithm, used for ranking, classification and many other machine learning tasks.
#
# Since it is based on decision tree algorithms, it splits the tree leaf wise with the best fit whereas other boosting algorithms split the tree depth wise or level wise rather than leaf-wise. So when growing on the same leaf in Light GBM, the leaf-wise algorithm can reduce more loss than the level-wise algorithm and hence results in much better accuracy which can rarely be achieved by any of the existing boosting algorithms. Also, it is surprisingly very fast, hence the word ‘Light’.

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-3.png')

# %% [markdown]
# We used 4 datasets in our experiment related to fraud prevention in the e-commerce world, with a binary target variable indicating whether an order made by a customer was fraudulent or legitimate. These example training datasets have around 300 features, a relatively high portion (~⅓) of categorical features and roughly 100K observations.
# The metric we use is weighted AUC (WAUC), which is similar to AUC but allows the use of different weights to different classes. In our real world data, we have orders that were declined and we can only partially tag them. Therefore, we gave these orders a lower weight in the AUC calculation. Our adjusted metric will be further presented in a future blog.
# In all experiments we trained on CPU, using an AWS c4.xlarge instance.

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-1.png')

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-2.png')

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-11.png')

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-4.png')

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-9.png')

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-5.png')

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-7.png')

# %%
from IPython.display import Image
Image(filename=r'D:\python\Interview-Prepartion-Data-Science-master\Lesson96-8.png')

# %% [markdown]
# #### Missing Values
#
# Yes

# %% [markdown]
# #####  2. Advantages

# %% [markdown]
# ##### 3. Disadvantages
# It requires some amount of parameter tuning

# %% [markdown]
# ##### 4. Whether Feature Scaling is required?
# No
#
# ##### 5. Impact of outliers?
# Robust to Outliers

# %% [markdown]
# ##### Types of Problems it can solve(Supervised)
# 1. Classification
# 2. Regression

# %% [markdown]
# ##### Performance Metrics

# %% [markdown]
# ##### Classification
# 1. Confusion Matrix
# 2. Precision,Recall, F1 score
#
# ##### Regression
# 1. R2,Adjusted R2
# 2. MSE,RMSE,MAE
