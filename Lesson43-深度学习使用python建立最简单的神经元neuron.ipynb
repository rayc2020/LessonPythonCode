# %% [markdown]
# ## 第43课 深度学习使用python建立最简单的神经元neuron
#
# Python零基础学习建模：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-DL12.png')

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-DL.png')

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-NN3.jpeg')

# %% [markdown]
# https://www.ibm.com/cloud/blog/ai-vs-machine-learning-vs-deep-learning-vs-neural-networks#:~:text=Deep%20learning%20is%20a%20subfield,must%20have%20more%20than%20three.

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-NN2.jpeg')

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-DL7.png')

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-NN1.jpeg')

# %%
x = np.linspace(-10, 10, 100) 
z = 1/(1 + np.exp(-x)) 
  
plt.plot(x, z) 
plt.xlabel("x") 
plt.ylabel("Sigmoid(X)") 
  
plt.show()

# %% [markdown]
# Inputs are fed into the perceptron
#
# Weights are multiplied to each input
#
# Summation and then add bias
#
# Activation function is applied. Note that here we use a step function, but there are other more sophisticated activation functions like sigmoid, hyperbolic tangent (tanh), rectifier (relu) and more. No worries, we will cover many of them in the future!
#
# Output is either triggered as 1, or not, as 0. Note we use y hat to label output produced by our perceptron model

# %% [markdown]
# ### Neural networks can be used for either regression or classification. Under regression model a single value is outputted which may be mapped to a set of real numbers meaning that only one output neuron is required

# %% [markdown]
# ### Logistic regression is a binary classification method. It can be modelled as a function that can take in any number of inputs and constrain the output to be between 0 and 1.  This means, we can think of Logistic Regression as a one-layer neural network.

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-NN4.jpg')

# %% [markdown]
# ### Predicting if a person would buy life insurnace based on his age using logistic regression

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Lesson43-Insurance.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker='o',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 20   21
# 5    56
# 1    25
# 21   26
# 25   54
# 22   40

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.89814428, 0.10185572],
#        [0.12726143, 0.87273857],
#        [0.84657078, 0.15342922],
#        [0.83072155, 0.16927845],
#        [0.1556466 , 0.8443534 ],
#        [0.48747345, 0.51252655]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([0, 1, 0, 0, 1, 1], dtype=int64)

# %%
y_test
# Out:
# 20    0
# 5     1
# 1     0
# 21    0
# 25    1
# 22    1
# Name: bought_insurance, dtype: int64

# %% [markdown]
# ### model.coef_ indicates value of m in y=m*x + b equation

# %%
model.coef_
# Out:
# array([[0.11720474]])

# %% [markdown]
# ### model.intercept_ indicates value of b in y=m*x + b equation

# %%
model.intercept_
# Out:
# array([-4.638073])

# %% [markdown]
# ### Lets defined sigmoid function now and do the math

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = model.coef_[0][0] * age + model.intercept_[0]
    y = sigmoid(z)
    return y

# %%
age = 26
prediction_function(age)
# Out:
# 0.16927844550360494

# %%
age = 47
prediction_function(age)
# Out:
# 0.7048601053948814

# %%
plt.scatter(df.age,df.bought_insurance,marker='o',color='red')

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-DL11.png')

# %%
x = df.age
z = prediction_function(df.age)
  
plt.plot(x, z) 
plt.xlabel("df.age") 
plt.ylabel("Sigmoid(df.age)") 
  
plt.show()

# %%
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson43-NN4.jpg')

# %%
x = np.linspace(-10, 10, 100) 
z = 1/(1 + np.exp(-x)) 
  
plt.plot(x, z) 
plt.xlabel("x") 
plt.ylabel("Sigmoid(X)") 
  
plt.show()
