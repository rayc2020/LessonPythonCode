# %% [markdown]
# ## 第90讲 When Decision Tree is Better Than Logistic Regression? Interview Q
#
# ## Python学习：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# ## Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode

# %% [markdown]
# (1)Decision Trees are non-linear classifiers; they do not require data to be linearly separable. When you are sure that your data set divides into two separable parts, then use a Logistic Regression. If you're not sure, then go with a Decision Tree

# %%
#Separable in space
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson90-4.png')

# %%
#Non-linearly separable data
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson90-5.png')

# %% [markdown]
# (2)For identifying risk factors, tree-based methods such as CART and conditional inference tree analysis may outperform logistic regression

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson90-7.png')

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson90-8.png')

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson90-8.jpg')

# %% [markdown]
# Greedy meaning that at step it makes the most optimal decision and recursive meaning it splits the larger question into smaller questions and resolves them the same way
#
# A decision tree or a classification tree is a tree in which each internal (non-leaf) node is labeled with an input feature. ... This process of top-down induction of decision trees (TDIDT) is an example of a greedy algorithm, and it is by far the most common strategy for learning decision trees from data

# %% [markdown]
# A decision tree is a way of representing knowledge obtained in the inductive learning process. The space is split using a set of conditions, and the resulting structure is the tree
#
# Decision tree builds regression or classification models in the form of a tree structure. ... The topmost decision node in a tree which corresponds to the best predictor called root node. Decision trees can handle both categorical and numerical data.

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson90-9.png')
