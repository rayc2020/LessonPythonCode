# %% [markdown]
# ## 第85讲 Python学习85讲-如何使用Feature Scaling？什么时候使用？面试题
#
# ## Python学习：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# ## Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson85-3.png')

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson85-4.png')

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson85-5.png')

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson85-6.jpg')

# %%
1.standardalization
2.normalization
3.robust
4.normalizer

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson28-scaling.png')
