# %% [markdown]
# ## 第94讲 万金油-Random Forest 特性? Interview Q
#
# ## Python学习：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# ## Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode

# %%
from IPython.display import Image
Image(filename='D:\python\Interview-Prepartion-Data-Science-master\Lesson94-2.png')

# %% [markdown]
# #### Important properties of Random Forest Classifiers
#
# 1. Decision Tree---Low Bias And High Variance
#
# 2. Ensemble Bagging(Random Forest Classifier)--Low Bias And Low Variance

# %% [markdown]
# #####  2. Advantages
# Advantages of Random Forest
#
# 1. <b>Doesn't Overfit<b>
#
# 2. Favourite algorithm for Kaggle competition
#
# 3. Less Parameter Tuning required
#
# 4. Decision Tree can handle both continuous and categorical variables.
#
# 5. No feature scaling required: No feature scaling (standardization and normalization) required in case of Random Forest as it uses DEcision Tree internally
#
# 6. Suitable for any kind of ML problems

# %% [markdown]
# ##### 3. Disadvantages
# Disadvantages of Random Forest
#
# Drawbacks
# -Model interpretability: Random forest models are not all that interpretable; they are like black boxes.
# Random forest is a predictive modeling tool and not a descriptive tool.
# -For very large data sets, the size of the trees can take up a lot of memory.
# -It can tend to overfit, so you should tune the hyperparameters.

# %% [markdown]
# ##### 4. Whether Feature Scaling is required?
# No
#
# ##### 5. Impact of outliers?
# Robust to Outliers

# %% [markdown]
# ##### Types of Problems it can solve(Supervised)
# 1. Classification
# 2. Regression

# %% [markdown]
# #### Practical Implementation
# 1. https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
# 2. https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html
#
# 1. https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# 2. https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html

# %% [markdown]
# ##### Performance Metrics

# %% [markdown]
# ##### Classification
# 1. Confusion Matrix
# 2. Precision,Recall, F1 score
#
# ##### Regression
# 1. R2,Adjusted R2
# 2. MSE,RMSE,MAE

# %% [markdown]
# Boosting - Low Bias And Low Variance
#
# Usually there is a trade-off between bias and variance. A model with low bias tends to have a high variance, and vice versa.
#
# Boosting is a meta-learning algorithm that reduces both bias and variance. The prediction after boosting is a weighted average of the predictions by multiple weak models.
#
# The model based on boosting tries to reduce the error in predictions by, for example, focusing on poor predictions and trying to model them better in the next iteration, and hence reduces bias.
#
# The boosting algorithm takes a weighted average of many weak models, and hence the final model has lower variance than each of the weak models.
