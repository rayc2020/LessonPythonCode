# %% [markdown]
# ## 第69讲 应用Keras Vgg16, Vgg19, Resnet等模型图像识别CNN
#
#
# ## Python学习：https://www.ixigua.com/home/77346806707?utm_source=xiguastudio
#
# ## Python源文件及数据下载链接: https://github.com/rayc2020/LessonPythonCode

# %% [markdown]
# VGG16 is a convolutional neural network model proposed by K. Simonyan and A. Zisserman from the University of Oxford in the paper “Very Deep Convolutional Networks for Large-Scale Image Recognition”. The model achieves 92.7% top-5 test accuracy in ImageNet, which is a dataset of over 14 million images belonging to 1000 classes. It was one of the famous model submitted to ILSVRC-2014(Large Scale Visual Recognition Challenge). It makes the improvement over AlexNet by replacing large kernel-sized filters (11 and 5 in the first and second convolutional layer, respectively) with multiple 3×3 kernel-sized filters one after another. VGG16 was trained for weeks and was using NVIDIA Titan Black GPU’s.
#
# VGG16 (also called OxfordNet) is a convolutional neural network architecture named after the Visual Geometry Group from Oxford, who developed it. It was used to win the ILSVR (ImageNet) competition in 2014
#
# ResNet, short for Residual Networks is a classic neural network used as a backbone for many computer vision tasks
#
# https://keras.io/api/applications/

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson69-vgg16-1.png')

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson69-vgg16-2.png')

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson69-vgg-3.png')

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson69-vgg-4.png')

# %%
from IPython.display import Image
Image(filename='D:\\python\\Project0-Python-MachineLearning\\Lesson69-5.png')

# %%
#https://www.kaggle.com/c/dogs-vs-cats/data

# %%
# Keras
from tensorflow.keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
model=VGG16(weights="imagenet")
model1=VGG19(weights="imagenet")
model2=ResNet50(weights="imagenet")

# %%
model.save('vgg19.h5')
model.save('vgg16.h5')
model.save('ResNet50.h5')

# %%
#from tensorflow.keras.models import load_model
#model = load_model( 'vgg16.h5')

# %%
img = image.load_img('D:/python/Project0-Python-MachineLearning/Lesson69/test1/cats/7.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)

print(classes)
# Out:
# [[4.90920456e-07 2.61017863e-06 1.15202449e-04 6.86419662e-05
#   2.23880543e-05 9.74747090e-05 3.27209455e-05 2.65740118e-06
#   2.10155304e-05 2.71945714e-06 4.85337779e-08 7.87563152e-08
#   5.10682730e-06 9.76216506e-06 1.86421445e-07 2.05235192e-05
#   2.99709700e-06 2.03591826e-05 1.78691459e-06 2.87482521e-07
#   2.55505688e-06 1.18389366e-07 7.62313618e-07 2.78460038e-06
#   3.81600512e-06 6.19503879e-08 1.25764402e-07 2.77970656e-07
#   1.78429023e-08 6.95568815e-07 2.56612736e-07 1.81164992e-07
#   2.84420906e-07 5.01086333e-07 5.32762613e-07 1.56893316e-06
#   6.72715657e-07 1.30569117e-06 9.62973900e-07 2.19313915e-06
#   3.94740573e-06 5.57846079e-07 2.62143033e-07 1.20472919e-06
#   8.51573532e-06 2.30028576e-07 9.03783985e-06 6.94084463e-07
#   2.38459847e-07 8.69803500e-07 1.44820297e-06 1.62412864e-04
#   1.41966404e-06 4.96086614e-07 3.14432032e-06 4.87639682e-07
#   1.79893746e-07 2.96854978e-07 9.46713499e-07 6.51962409e-07
# ...

# %%
classes.shape
# Out:
# (1, 1000)

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string

# %%
result
# Out:
# 'tabby'

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F8B3808F48>

# %%
img = image.load_img('D:/python/Project0-Python-MachineLearning/Lesson69/test1/cats/10.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)

print(classes)
# Out:
# [[8.65970691e-08 7.31814509e-07 3.64791077e-07 1.88396484e-07
#   2.43644763e-06 3.89984450e-07 7.05126482e-08 3.06895186e-06
#   3.64970656e-05 8.91675882e-07 7.94451349e-09 6.16159426e-08
#   2.95597324e-08 1.16657411e-07 1.10323475e-08 3.20574536e-08
#   1.27385022e-07 4.51845062e-06 5.90402465e-07 3.82123702e-08
#   4.14112726e-08 4.29097867e-07 5.99365748e-08 2.00823379e-07
#   8.75249810e-08 3.39225750e-08 7.17468307e-09 4.40724861e-08
#   3.10132435e-08 8.72572841e-08 8.37689473e-09 6.46436860e-08
#   3.92292288e-09 8.76714701e-09 3.96122211e-08 6.02432504e-09
#   3.12502557e-08 2.97422051e-08 3.07883511e-07 4.09858423e-08
#   3.02144230e-07 3.09624433e-08 5.22868824e-08 4.56993838e-08
#   3.38668968e-07 2.76140444e-08 9.36121978e-07 1.11459268e-08
#   1.40934810e-08 7.79175924e-09 1.30132051e-07 2.70383566e-07
#   2.08553388e-07 4.77692019e-08 3.05738183e-07 7.76210385e-08
#   2.74057498e-07 2.18091838e-08 6.58364954e-08 4.14469696e-07
# ...

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string
print(result)
# Out:
# Egyptian_cat

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F95C77E5C8>

# %%
img = image.load_img('D:/python/Project0-Python-MachineLearning/Lesson69/test1/dogs/3.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)

print(classes)
# Out:
# [[4.97021858e-07 2.00974114e-06 6.86972612e-08 8.74697577e-08
#   4.21956997e-07 2.68753365e-06 1.25363243e-07 5.21708159e-07
#   5.80165215e-06 6.02117268e-07 3.88330761e-07 9.33056128e-07
#   4.90074945e-06 4.77199706e-07 4.58508993e-07 4.43569718e-07
#   7.79969355e-07 4.06201707e-07 3.24387315e-07 6.99332759e-07
#   8.14055795e-07 1.11979762e-06 5.14184421e-07 9.35898129e-07
#   1.76116816e-06 3.00440121e-07 1.39025224e-06 6.16897125e-07
#   1.38625452e-07 9.27098199e-07 1.65350912e-07 8.73780948e-07
#   5.58219085e-07 2.28260006e-07 3.23733047e-07 5.90231153e-08
#   4.53616423e-07 1.29139949e-07 1.65611880e-06 1.37834036e-06
#   1.47949947e-06 2.06601067e-06 2.27992314e-06 1.88767285e-06
#   4.21549970e-07 1.84607302e-07 2.82309679e-06 3.12561610e-06
#   3.67660647e-07 1.06712370e-07 3.16497790e-07 1.17414675e-06
#   4.23241829e-07 1.15974785e-07 2.26459278e-07 1.85430778e-07
#   2.24745392e-07 1.21019482e-07 2.17642977e-07 1.16658828e-06
# ...

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string
print(result)
# Out:
# golden_retriever

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F956770088>

# %%
img = image.load_img('D:/python/Project0-Python-MachineLearning/Lesson69/test1/dogs/dog.9758.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model1.predict(img_data)

print(classes)
# Out:
# [[2.04884472e-07 4.06496184e-07 2.99047791e-08 1.31290028e-08
#   2.86248081e-07 6.58661634e-07 6.64028619e-08 1.58266303e-07
#   1.74777810e-07 1.02967030e-08 3.81388645e-08 7.63212782e-08
#   4.02392821e-08 3.37877424e-08 6.17090876e-08 2.88351636e-08
#   6.16768148e-09 1.63840056e-07 5.43009406e-08 7.29017344e-08
#   4.19229167e-08 6.09932940e-08 6.91785162e-09 6.90845425e-08
#   2.61733657e-08 2.52866840e-07 1.82244534e-07 1.73363446e-07
#   8.71460131e-08 3.17027720e-08 1.53559867e-07 2.70913972e-07
#   1.77972868e-06 1.49860242e-07 1.79066546e-06 1.30997435e-07
#   4.47696038e-06 4.18432933e-07 3.07839628e-06 5.40804734e-08
#   2.32640923e-06 9.33759225e-07 7.16879822e-06 3.26447605e-07
#   1.35281226e-07 2.15107416e-08 7.55848134e-07 8.76103243e-08
#   4.97334440e-08 9.92919258e-09 3.86458083e-08 1.43371448e-08
#   8.80593092e-08 1.10371410e-07 7.53390452e-07 9.77498047e-08
#   5.59507725e-07 7.54811893e-08 2.26057239e-07 8.48748925e-07
# ...

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string
print(result)
# Out:
# beagle

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F907FC2408>

# %%
img = image.load_img('D:/python/Project0-Python-MachineLearning/Lesson69/test1/cats/123.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model2.predict(img_data)

print(classes)
# Out:
# [[7.22379400e-06 3.28042515e-05 2.75456350e-05 8.77341590e-05
#   2.78756896e-04 7.81472889e-04 8.39861750e-05 3.06800066e-05
#   2.08771715e-04 5.25130372e-06 5.97257167e-06 3.75205695e-06
#   6.79438244e-06 5.57732028e-06 3.20246522e-06 5.04631180e-06
#   2.51619554e-06 1.75124260e-05 2.28785302e-05 2.28910244e-06
#   7.94412063e-06 1.25014431e-05 9.57119482e-06 2.35821390e-05
#   2.12325676e-06 1.77375148e-06 3.71295528e-06 1.46834759e-06
#   2.61395303e-06 1.00814934e-04 2.52841551e-06 6.91330843e-06
#   2.14651777e-06 9.20515595e-05 3.05157791e-05 2.53767962e-06
#   2.90875232e-05 4.05002493e-06 1.33037456e-05 2.28468070e-05
#   5.47179889e-06 1.93609339e-05 4.41693692e-06 9.38129233e-06
#   1.28231713e-05 1.39715148e-05 2.99183303e-05 1.35446262e-05
#   1.42751896e-05 4.10643452e-06 1.99601654e-05 2.84715294e-04
#   2.16981734e-05 4.67349810e-06 1.69447248e-05 2.07941630e-05
#   1.84780401e-06 2.06955292e-06 1.33129597e-05 5.71721648e-06
# ...

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string
print(result)
# Out:
# lynx

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F907FAC888>

# %%
img = image.load_img('D:/python/Project0-Python-MachineLearning/Lesson69/test1/dogs/18.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model1.predict(img_data)

print(classes)

# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string
print(result)
img
# Out:
# [[1.51254726e-05 2.56937653e-07 2.72908778e-06 1.97897907e-06
#   5.80608503e-06 4.28519888e-06 1.59320996e-06 7.68225675e-07
#   1.20770608e-06 1.08215238e-06 1.24895519e-06 1.67855774e-06
#   2.16772520e-07 3.63540698e-06 1.65597805e-06 3.30967936e-07
#   1.76295856e-07 9.60853322e-06 1.11707232e-06 3.02217609e-06
#   3.64085594e-07 1.01316380e-06 3.26370440e-07 4.05752985e-07
#   1.54204781e-06 5.87638533e-06 3.15502507e-06 1.14891600e-06
#   7.43688270e-06 8.71356804e-07 1.53012195e-06 2.53019948e-06
#   4.17770116e-06 2.18632476e-06 6.10313009e-06 2.92391860e-06
#   8.70201256e-06 2.94873780e-06 5.02596959e-06 7.45866998e-07
#   2.33626565e-06 1.96546148e-06 1.41685450e-06 5.25997507e-07
#   5.04385355e-07 1.62195875e-07 3.02630633e-06 1.11406359e-06
#   2.15665025e-07 1.02542924e-06 1.76293906e-06 1.77100412e-06
#   9.98286851e-07 3.83245242e-06 1.19354138e-06 2.23638813e-06
#   1.25442114e-06 1.28874262e-06 2.63662514e-06 3.46433080e-06
# ...
